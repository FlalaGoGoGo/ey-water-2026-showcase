# %% [markdown]
# # Round 18 DRP Ultralight Notebook Brief
#
# This curated notebook brief represents one of the careful DRP probes from the middle of the project.
#
# ## What this stage represented
# - DRP was consistently the hardest target to improve without hurting total score.
# - We tested extremely light DRP changes alongside stronger TA control logic.
# - The point was not only to find gains, but to learn the cost of touching DRP at all.
#
# ## Why it matters in the showcase
# - It makes the experiment program look real and balanced across all three targets.
# - It also documents a recurring lesson: some variables require much tighter risk control than others.
